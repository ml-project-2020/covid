# %%
import sys
import pandas as pd
import numpy as np

# %load_ext autoreload
# %autoreload 2

sys.path.insert(1, './data/')
import health_data as health_data

# %%
# health data by state
ensanut = health_data.get_ensanut()
ensanut.head()
# Out:
#          Diabetes  Hipertension  Tabaquismo  POB_20_MAS_2018  Cardiovascular  \
# CVE_GEO
# 1           65487        126227    200182.0           858654             0.0
# 2          247659        516012    437796.0          2456298          2120.0
# 3           47555         93546    112282.0           565680             0.0
# 4           88036        163436     76876.0           625996           635.0
# 5          253158        455245    454164.0          2032566           682.0
#
#          Porcentaje_Diabetes  Porcentaje_Hipertension  Porcentaje_Tabaquismo  \
# CVE_GEO
# 1                   0.076267                 0.147006               0.233135
# 2                   0.100826                 0.210077               0.178234
# 3                   0.084067                 0.165369               0.198490
# 4                   0.140633                 0.261082               0.122806
# 5                   0.124551                 0.223976               0.223444
#
# ...

# %%
# hospital data by hospital
hospitals = health_data.get_hospital_data()
hospitals.head()
# Out:
#     Clave Estado   Nombre Estado  Clave Municipio Nombre Municipio  \
# 0              1  AGUASCALIENTES                1   AGUASCALIENTES
# 1              1  AGUASCALIENTES                1   AGUASCALIENTES
# 14             1  AGUASCALIENTES                5      JESÚS MARÍA
# 16             1  AGUASCALIENTES                1   AGUASCALIENTES
# 28             1  AGUASCALIENTES                1   AGUASCALIENTES
#
#     Número de Consultorios de Epidemiología  \
# 0                                         0
# 1                                         0
# 14                                        1
# 16                                        0
# 28                                        0
#
#     Número de Consultorios de Infectología  \
# 0                                        0
# 1                                        0
# 14                                       0
# 16                                       0
# 28                                       0
#
# ...

# %%
# population data by state
conapo = health_data.get_conapo()
conapo.head()
# Out:
#      CVE_GEO  EDAD_MED  POB_MIT_AÑO  POB_12_14  POB_15_17  POB_15_19  \
# 151        1     27.00      1434635      80285      80698     133976
# 232        2     28.74      3634868     184400     186875     312423
# 313        3     28.51       804708      40003      40181      67198
# 394        4     28.00      1000617      51364      50987      84871
# 475        5     28.00      3218720     167697     167040     277265
#
#      POB_15_29  POB_15_49  POB_18_24  POB_20_24  POB_3_5  POB_30_64  POB_6_11  \
# 151     389147     774999     183623     130345    75951     566069    157335
# 232     949062    1999516     443050     317502   181944    1546605    364994
# 313     206768     445051      96038      69021    42210     343153     81766
# 394     258774     541300     119854      85970    54496     408709    106131
# 475     807595    1675574     380384     270159   180285    1308527    342806
#
#      POB_65_MAS
# 151       91933
# 232      231497
# 313       48966
# ...

# %%
# territory area by state
territory = health_data.get_territory()
territory.head()
# Out:
#    CVE_GEO     Km2
# 0        1    5589
# 1        2   70113
# 2        3   73677
# 3        4   51833
# 4        5  151571

# %%
# merged data
data_all = health_data.merge_data()
data_all.head()
# Out:
#    CVE_GEO  EDAD_MED  POB_MIT_AÑO  POB_12_14  POB_15_17  POB_15_19  POB_15_29  \
# 0        1     27.00      1434635      80285      80698     133976     389147
# 1        2     28.74      3634868     184400     186875     312423     949062
# 2        3     28.51       804708      40003      40181      67198     206768
# 3        4     28.00      1000617      51364      50987      84871     258774
# 4        5     28.00      3218720     167697     167040     277265     807595
#
#    POB_15_49  POB_18_24  POB_20_24  ...  Total de unidades de Hospitalizacion  \
# 0     774999     183623     130345  ...                                    11
# 1    1999516     443050     317502  ...                                    25
# 2     445051      96038      69021  ...                                    19
# 3     541300     119854      85970  ...                                    22
# 4    1675574     380384     270159  ...                                    47
#
# ...
